# %%
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np

# %%
df=pd.read_csv("COVID-19.csv",low_memory=False)

# %% [markdown]
# # Analysing the Data

# %%
df.describe()
# Out:
#           Unnamed: 0  People_Total_Tested_Count          Cases     Difference  \
# count  650000.000000               4.060000e+03  650000.000000  650000.000000
# mean   324999.500000               1.681966e+05     361.531489       9.814488
# std    187638.981824               2.651954e+05    6180.092436     199.710318
# min         0.000000               3.000000e+00       0.000000  -10034.000000
# 25%    162499.750000               2.979575e+04       0.000000       0.000000
# 50%    324999.500000               7.891900e+04       0.000000       0.000000
# 75%    487499.250000               1.905130e+05       5.000000       0.000000
# max    649999.000000               2.293032e+06  614941.000000   33274.000000
#
#                 FIPS            Lat           Long  Population_Count  \
# count  559863.000000  630695.000000  630695.000000      6.306950e+05
# mean    30323.241432      36.532844     -79.520216      3.230421e+06
# ...

# %% [markdown]
# # First work on is any null values and duplicated values are present ?

# %%
df.isna().sum()
# Out:
# Unnamed: 0                                   0
# Case_Type                                    0
# People_Total_Tested_Count               645940
# Cases                                        0
# Difference                                   0
# Date                                         0
# Combined_Key                                 0
# Country_Region                               0
# Province_State                           49044
# Admin2                                   71121
# iso2                                      1072
# iso3                                       804
# FIPS                                     90137
# Lat                                      19305
# Long                                     19305
# Population_Count                         19305
# People_Hospitalized_Cumulative_Count    645940
# Data_Source                                  0
# Prep_Flow_Runtime                            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop("People_Total_Tested_Count",inplace=True,axis=1)

# %%
df.drop("People_Hospitalized_Cumulative_Count",inplace=True,axis=1)

# %%
df.sample(10)
# Out:
#         Unnamed: 0  Case_Type  Cases  Difference       Date  \
# 482501      482501     Deaths    158           0   6/1/2020
# 381837      381837  Confirmed     72           6  5/24/2020
# 575115      575115  Confirmed    220           2  4/27/2020
# 371531      371531  Confirmed      0           0  1/30/2020
# 41392        41392     Deaths      1           0  3/27/2020
# 273129      273129     Deaths      0           0  2/15/2020
# 485949      485949     Deaths      0           0  2/26/2020
# 226657      226657     Deaths      0           0  2/15/2020
# 466252      466252     Deaths      0           0   3/7/2020
# 42277        42277  Confirmed   2274         143  4/29/2020
#
#                          Combined_Key Country_Region  Province_State  \
# 482501     St. Tammany, Louisiana, US             US       Louisiana
# 381837       Kittitas, Washington, US             US      Washington
# 575115         Sonoma, California, US             US      California
# ...

# %%
len(df)
# Out:
# 650000

# %%
(90137/650000)*100
# Out:
# 13.86723076923077

# %% [markdown]
# # almost 13.86 % of data we lose if we remove the row which contain the null values

# %% [markdown]
# ## so we should fill the values by imputation

# %%
mean_values = df["FIPS"].mean()
df["FIPS"].fillna(mean_values,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650000 entries, 0 to 649999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         650000 non-null  int64
#  1   Case_Type          650000 non-null  object
#  2   Cases              650000 non-null  int64
#  3   Difference         650000 non-null  int64
#  4   Date               650000 non-null  object
#  5   Combined_Key       650000 non-null  object
#  6   Country_Region     650000 non-null  object
#  7   Province_State     600956 non-null  object
#  8   Admin2             578879 non-null  object
#  9   iso2               648928 non-null  object
#  10  iso3               649196 non-null  object
#  11  FIPS               650000 non-null  float64
#  12  Lat                630695 non-null  float64
#  13  Long               630695 non-null  float64
#  14  Population_Count   630695 non-null  float64
# ...

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# Case_Type            0
# Cases                0
# Difference           0
# Date                 0
# Combined_Key         0
# Country_Region       0
# Province_State       0
# Admin2               0
# iso2                 0
# iso3                 0
# FIPS                 0
# Lat                  0
# Long                 0
# Population_Count     0
# Data_Source          0
# Prep_Flow_Runtime    0
# dtype: int64

# %%
len(df)
# Out:
# 560378

# %%
df.to_csv("Cleaned_COVID_19.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.to_csv("Cleaned_COVID_19.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
# ...

# %%
df.sample(20)
# Out:
#         Unnamed: 0  Case_Type  Cases  Difference       Date  \
# 310796      310796     Deaths     16           0  5/15/2020
# 535043      535043     Deaths      0           0  1/28/2020
# 213552      213552     Deaths      0           0  2/19/2020
# 562006      562006     Deaths      1           0  5/19/2020
# 406912      406912     Deaths      0           0  3/27/2020
# 641815      641815  Confirmed      9           0   5/9/2020
# 243403      243403  Confirmed    164           1  5/21/2020
# 195033      195033     Deaths      0           0   3/8/2020
# 281875      281875  Confirmed    105           1  5/31/2020
# 457585      457585  Confirmed      0           0  4/10/2020
# 601514      601514     Deaths      0           0  3/29/2020
# 538929      538929  Confirmed      5           0   5/8/2020
# 629710      629710  Confirmed     27           0  4/28/2020
# 291995      291995  Confirmed      4           0  5/16/2020
# 399318      399318  Confirmed      0           0   3/4/2020
# ...

# %%
c
for i in range(0,len(df)):
    if(df['Country_Region'].iloc() == "US"):
        c=c+1
c
